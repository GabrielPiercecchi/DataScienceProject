# %% [markdown]
# # Chatbot sulla scelta del PC Portatile migliore per l'utente

# %% [markdown]
# ## ETL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import ast
import scipy.stats as stats
import plotly.express as px
import re

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.mixture import GaussianMixture
from sklearn.neighbors import NearestNeighbors

# %%
file = 'laptops.csv'
laptops = pd.read_csv(file)
laptops.head()
# Out:
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
# 2           2  https://rukminim1.flixcart.com/image/312/312/l...
# 3           3  https://rukminim1.flixcart.com/image/312/312/x...
# 4           4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  price(in Rs.)  \
# 0             Lenovo Intel Core i5 11th Gen          62990
# 1            Lenovo V15 G2 Core i3 11th Gen          37500
# 2      ASUS TUF Gaming F15 Core i5 10th Gen          49990
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen          33990
# 4                   Lenovo Athlon Dual Core          18990
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# 2  Intel Core i5 Processor (10th Gen)   8 GB DDR4 RAM
# 3  Intel Core i3 Processor (10th Gen)   8 GB DDR4 RAM
# 4      AMD Athlon Dual Core Processor   4 GB DDR4 RAM
#
#                                    os              storage  display(in inch)  \
# 0         Windows 11 Operating System           512 GB SSD              15.6
# 1  64 bit Windows 11 Operating System  1 TB HDD|256 GB SSD              15.6
# 2         Windows 11 Operating System           512 GB SSD              15.6
# 3  64 bit Windows 11 Operating System           512 GB SSD              15.6
# 4                DOS Operating System           256 GB SSD              14.0
#
#    rating  no_of_ratings  no_of_reviews
# 0     4.5           14.0            1.0
# 1     4.4           53.0            3.0
# 2     4.4         4733.0          463.0
# 3     4.3        10406.0         1040.0
# 4     3.8           18.0            3.0

# %%
laptops.isnull().sum()
# Out:
# Unnamed: 0            0
# img_link              0
# name                  0
# price(in Rs.)         0
# processor             0
# ram                   0
# os                    0
# storage               0
# display(in inch)      0
# rating              296
# no_of_ratings       296
# no_of_reviews       296
# dtype: int64

# %%
laptops= laptops.dropna()
laptops.to_csv('laptops_cleaned.csv', index=False)
laptops.isnull().sum()
# Out:
# Unnamed: 0          0
# img_link            0
# name                0
# price(in Rs.)       0
# processor           0
# ram                 0
# os                  0
# storage             0
# display(in inch)    0
# rating              0
# no_of_ratings       0
# no_of_reviews       0
# dtype: int64

# %%
# Carica il dataset
df = pd.read_csv("laptops_cleaned.csv")

# Controlliamo che la colonna "price(in Rs.)" esista nel dataset
if "price(in Rs.)" in df.columns:
    # Conversione INR -> EUR (tasso di cambio approssimativo)
    exchange_rate = 0.011
    df["price(in EUR)"] = df["price(in Rs.)"] * exchange_rate

    # Rimuove la colonna con la valuta vecchia
    df.drop(columns=["price(in Rs.)"], inplace=True)

    # Salva il nuovo dataset con i prezzi aggiornati
    new_filename = "laptops_etl.csv"
    df.to_csv(new_filename, index=False)

    print(f"✅ Conversione completata! Dataset salvato come '{new_filename}'.")

    # Mostra un'anteprima per verifica
    display(df.head())
else:
    print("❌ Errore: la colonna 'price(in Rs.)' non è presente nel dataset.")
# Out:
# ✅ Conversione completata! Dataset salvato come 'laptops_etl.csv'.
#    Unnamed: 0                                           img_link  \
# 0           0  https://rukminim1.flixcart.com/image/312/312/x...
# 1           1  https://rukminim1.flixcart.com/image/312/312/x...
# 2           2  https://rukminim1.flixcart.com/image/312/312/l...
# 3           3  https://rukminim1.flixcart.com/image/312/312/x...
# 4           4  https://rukminim1.flixcart.com/image/312/312/x...
#
#                                        name  \
# 0             Lenovo Intel Core i5 11th Gen
# 1            Lenovo V15 G2 Core i3 11th Gen
# 2      ASUS TUF Gaming F15 Core i5 10th Gen
# 3  ASUS VivoBook 15 (2022) Core i3 10th Gen
# 4                   Lenovo Athlon Dual Core
#
#                             processor             ram  \
# 0  Intel Core i5 Processor (11th Gen)  16 GB DDR4 RAM
# 1  Intel Core i3 Processor (11th Gen)   8 GB DDR4 RAM
# 2  Intel Core i5 Processor (10th Gen)   8 GB DDR4 RAM
# 3  Intel Core i3 Processor (10th Gen)   8 GB DDR4 RAM
# 4      AMD Athlon Dual Core Processor   4 GB DDR4 RAM
#
#                                    os              storage  display(in inch)  \
# 0         Windows 11 Operating System           512 GB SSD              15.6
# 1  64 bit Windows 11 Operating System  1 TB HDD|256 GB SSD              15.6
# 2         Windows 11 Operating System           512 GB SSD              15.6
# 3  64 bit Windows 11 Operating System           512 GB SSD              15.6
# 4                DOS Operating System           256 GB SSD              14.0
#
#    rating  no_of_ratings  no_of_reviews  price(in EUR)
# 0     4.5           14.0            1.0         692.89
# 1     4.4           53.0            3.0         412.50
# 2     4.4         4733.0          463.0         549.89
# 3     4.3        10406.0         1040.0         373.89
# 4     3.8           18.0            3.0         208.89

# %%
laptosp_etl = df
laptosp_etl.isnull().sum()
# Out:
# Unnamed: 0          0
# img_link            0
# name                0
# processor           0
# ram                 0
# os                  0
# storage             0
# display(in inch)    0
# rating              0
# no_of_ratings       0
# no_of_reviews       0
# price(in EUR)       0
# dtype: int64

# %%
laptosp_etl= laptosp_etl.dropna()
laptosp_etl.to_csv("laptops_etl_clean.csv", index=False)
laptops_etl_clean = pd.read_csv("laptops_etl_clean.csv")
laptops_etl_clean.isnull().sum()
# Out:
# Unnamed: 0          0
# img_link            0
# name                0
# processor           0
# ram                 0
# os                  0
# storage             0
# display(in inch)    0
# rating              0
# no_of_ratings       0
# no_of_reviews       0
# price(in EUR)       0
# dtype: int64

# %%
# Carica il dataset
df = pd.read_csv("laptops_etl_clean.csv")

# Rimuovi i duplicati basandoti sulle colonne "name", "ram", "processor" e "storage"
df = df.drop_duplicates(subset=["name", "ram", "processor", "storage"])
print("Duplicati rimossi.")

# Definizione delle keywords che indicano l'inizio delle specifiche tecniche
keywords = ["Intel Core", "Core", "Ryzen", "Pentium", "Celeron", "M1", "M2"]

def clean_name(name):
    """
    Restituisce la parte di 'name' precedente alla prima occorrenza di una keyword.
    Se non viene trovata nessuna keyword, restituisce il nome intero.
    """
    indices = []
    for kw in keywords:
        match = re.search(re.escape(kw), name, re.IGNORECASE)
        if match:
            indices.append(match.start())
    if indices:
        cutoff = min(indices)
        return name[:cutoff].strip()
    else:
        return name.strip()

# Sovrascrivi la colonna "name" con la versione pulita
df["name"] = df["name"].apply(clean_name)

# Salva il nuovo dataset in un file CSV (senza l'indice)
df.to_csv("laptops_etl_clean.csv", index=False)

print("Dataset aggiornato: duplicati rimossi e colonna 'name' pulita. Il nuovo file è stato salvato come 'laptops_etl_clean.csv'.")
# Out:
# Duplicati rimossi.
# Dataset aggiornato: duplicati rimossi e colonna 'name' pulita. Il nuovo file è stato salvato come 'laptops_etl_clean.csv'.

# %%
# Ottieni i nomi delle colonne
columns_to_check = df.columns[2:3]

# Crea un dizionario per memorizzare le istanze univoche per ogni colonna
unique_instances = {}

# Itera attraverso le colonne e ottieni le istanze univoche
for col in columns_to_check:
    unique_instances[col] = df[col].unique()

# Stampa le istanze univoche per ogni colonna
for col, unique_vals in unique_instances.items():
    print(f"Colonna: {col}")
    print(unique_vals)
    print()
# Out:
# Colonna: name
# ['Lenovo' 'Lenovo V15 G2' 'ASUS TUF Gaming F15' 'ASUS VivoBook 15 (2022)'
#  'Lenovo Athlon Dual' 'APPLE 2020 Macbook Air' 'ASUS VivoBook 14 (2021)'
#  'RedmiBook Pro' 'acer Aspire 3' 'ASUS Vivobook 14 (2022)'
#  'ASUS Vivobook 15' 'ASUS' 'DELL Vostro' 'realme Book (Slim)' 'HP 14s'
#  'HP' 'MSI Bravo 15' 'ASUS Zenbook Flip 14 OLED (2022) Touch Panel'
#  'HP 15s' 'Lenovo IdeaPad 3' 'HP Athlon Dual'
#  'ASUS VivoBook K15 OLED (2022)' 'ASUS ROG Strix G15 (2022)'
#  'ASUS Vivobook Pro 15' 'SAMSUNG Galaxy Book Go Snapdragon 7c Gen 2'
#  'HP Pavilion' 'acer Swift 3'
#  'ASUS TUF Gaming F17 (2022) with 90Whr Battery' 'ASUS VivoBook 14'
#  'acer Extensa' 'ASUS VivoBook 14 (2022)' 'DELL'
#  'ASUS Vivobook Ultra 14 (2022)' 'ASUS Zenbook 14X (2022) Space Edition'
#  'MSI Alpha 15 AMD Advantage Edition' 'ASUS VivoBook K15 OLED'
#  'acer Aspire 7' 'ASUS Chromebook' 'ASUS Chromebook Flip Touch'
#  'ASUS Vivobook 16X' 'Infinix X1 Slim Series' 'Lenovo IdeaPad'
#  'ASUS ZenBook Duo 14 (2021) Touch Panel' 'acer Aspire 3 Dual'
#  'Lenovo IdeaPad 1' 'ASUS Vivobook 15 OLED (2022)'
#  'ASUS VivoBook 15 (2021)' 'ASUS TUF Dash F15 (2022)'
#  'ASUS Vivobook 15 Touch' 'HP OMEN' 'ASUS Vivobook Pro 15 OLED'
#  'MSI Sword 15' 'APPLE 2022 MacBook AIR'
#  'ASUS Vivobook S14 OLED (2022) Intel EVO'
#  'ASUS TUF Gaming A15 with 90Whr Battery' 'ASUS VivoBook Flip 14'
#  'HP Envy x360 Creator Intel Evo'
#  'ASUS TUF Gaming A17 (2022) with 90Whr Battery' 'Lenovo IdeaPad Gaming 3'
#  'APPLE MacBook Air' 'ASUS TUF Dash F15' 'realme Book(Slim) Intel Evo'
#  'DELL Inspiron' 'acer Predator Helios 300' 'MSI'
#  'ASUS ROG Zephyrus G15 (2022) with 90Whr Battery'
#  'Infinix INBook X2 Plus' 'DELL G15' 'APPLE 2021 Macbook Pro'
#  'ASUS Touchscreen' 'HP Victus' 'ASUS Zenbook 14 OLED (2022) Intel EVO'
#  'SAMSUNG' 'HP G8' 'ASUS Vivobook K15 OLED' 'APPLE 2022 MacBook Pro'
#  'ASUS ROG Strix G15' 'HP Chromebook x360 Intel'
#  'ASUS Vivobook Flip 14 (2022) Touch Panel' 'ASUS TUF Gaming F15 (2022)'
#  'ASUS ROG Strix G15 Advantage Edition' 'ASUS TUF Gaming A15'
#  'APPLE 2020 Macbook Pro' 'acer Nitro 5' 'MSI Katana GF66'
#  'ASUS ROG Strix SCAR 15 (2022)' 'ASUS Vivobook 14' 'HP Pavilion Gaming'
#  'MSI Crosshair 15' 'Lenovo Legion 5' 'MSI Delta 15 AMD Advantage Edition'
#  'ASUS ROG Strix G15 with 90Whr Battery' 'ASUS ROG Strix Scar 15 (2022)'
#  'ALIENWARE' 'DELL Inspiron 7000' 'Lenovo Legion 5 Pro'
#  'SAMSUNG Galaxy Book2' 'ASUS ROG Zephyrus G15 (2020)'
#  'Infinix ZERO BOOK Series Laptop' 'MSI Pulse GL66'
#  'Infinix INBook X1 Neo Series' 'MSI GP66 Leopard' 'ASUS TUF Gaming A17'
#  'ASUS TUF Gaming F17 (2022)' 'acer Travelmate'
#  'HP Envy x360 Creator OLED Intel Evo' 'ASUS ROG Zephyrus'
#  'Lenovo Yoga Slim 7 Pro' 'DELL Inspiron 3000' 'ASUS Zenbook 13 Intel EVO'
#  'Avita SATUS S111' 'HP Spectre Intel Evo' 'DELL Insprion 3511'
#  'ASUS VivoBook Ultra' 'acer Aspire 5' 'MSI GF65 Thin'
#  'ASUS VivoBook Gaming (2020)' 'HP Chromebook'
#  'Mi Notebook Horizon Edition 14' 'MSI GP65 Leopard' 'MSI Bravo'
#  'MSI Creator Z16' 'Lenovo IdeaPad Slim 5' 'ASUS EeeBook 12'
#  'APPLE MacBook Pro' 'ASUS (2022)' 'MSI Stealth' 'acer aspire 5 gaming'
#  'MSI GF63 Thin' 'ASUS ZenBook 13' 'Lenovo Ideapad Slim 3i (2021)'
#  'ASUS ROG' 'acer Intel EVO Swift 5' 'MSI Alpha 15' 'ASUS ExpertBook B9'
#  'ASUS ZenBook Classic'
#  'ASUS ROG Strix G15 Advantage Edition with 90Whr Battery' 'HP Envy x360'
#  'Lenovo Ideapad Gaming 3' 'ASUS Vivobook Flip' 'HP HP Pavilion'
#  'ASUS ROG Flow X13' 'Lenovo IdeaPad Gaming' 'ASUS ExpertBook P1'
#  'ASUS VivoBook Ultra 14 (2022)' 'MSI Prestige 14 Intel EVO'
#  'ASUS ZenBook Pro 15' 'MSI Prestige 14' 'HP HP Envy' 'Lenovo Ideapad AMD'
#  'Avita PURA APU Dual' 'ASUS ZenBook S' 'ASUS VivoBook 15'
#  'Lenovo IdeaPad 3 Dual' 'GIGABYTE G5 GD' 'acer Swift 5' 'HP 255 G8'
#  'ASUS VivoBook Ultra K15 OLED' 'ASUS TUF Gaming F17' 'acer Spin 7'
#  'MSI GL' 'Lenovo Ideapad 720S' 'MSI GP76' 'MSI GS'
#  'MICROSOFT Surface Laptop 3' 'DELL G7' 'Lenovo IdeaPad Flex 3 Chromebook'
#  'DELL Vostro 3000' 'ASUS Vivobook Gaming' 'HP 250 G8' 'DELL 7000 Series'
#  'RedmiBook 15' 'Lenovo Ideapad 520' 'HP Spectre x360' 'lenovo Yoga 7'
#  'DELL 5000' 'Lenovo B50' 'Vaio SE Series' 'MSI Modern 14'
#  'DELL Inspiron 3501' 'acer Aspire 5 Gaming' 'ASUS Vivobook'
#  'Lenovo Ideapad 330s' 'acer Nitro 5 Spin' 'DELL GAMING G5 SERIES'
#  'ASUS VivoBook S14' 'ASUS ROG Strix G15 (2022) with 90Whr Battery'
#  'ASUS TUF GAMING A15' 'Nokia PureBook S14' 'Lenovo IdeaPad 3 Chromebook'
#  'Vaio E Series' 'Avita Liber' 'HP Chromebook MediaTek Kompanio 500']

# %%
# Ottieni i nomi delle colonne
columns_to_check = df.columns[3:4]

# Crea un dizionario per memorizzare le istanze univoche per ogni colonna
unique_instances = {}

# Itera attraverso le colonne e ottieni le istanze univoche
for col in columns_to_check:
    unique_instances[col] = df[col].unique()

# Stampa le istanze univoche per ogni colonna
for col, unique_vals in unique_instances.items():
    print(f"Colonna: {col}")
    print(unique_vals)
    print()
# Out:
# Colonna: processor
# ['Intel Core i5 Processor (11th Gen)' 'Intel Core i3 Processor (11th Gen)'
#  'Intel Core i5 Processor (10th Gen)' 'Intel Core i3 Processor (10th Gen)'
#  'AMD Athlon Dual Core Processor' 'Apple M1 Processor'
#  'Intel Celeron Dual Core Processor' 'AMD Ryzen 3 Dual Core Processor'
#  'Intel Core i5 Processor (12th Gen)' 'Intel Core i7 Processor (11th Gen)'
#  'AMD Ryzen 5 Hexa Core Processor' 'Intel Core i3 Processor (12th Gen)'
#  'AMD Ryzen 3 Quad Core Processor' 'AMD Ryzen 7 Octa Core Processor'
#  'Qualcomm Snapdragon 7c Gen 2 Processor'
#  'Intel Core i7 Processor (12th Gen)' 'Intel Pentium Silver Processor'
#  'AMD Ryzen 5 Quad Core Processor' 'Intel Core i9 Processor (12th Gen)'
#  'AMD Dual Core Processor' 'Apple M2 Processor'
#  'AMD Ryzen 9 Octa Core Processor' 'Apple M1 Max Processor'
#  'Apple M1 Pro Processor' 'Intel Pentium Quad Core Processor'
#  'Intel Core i7 Processor (10th Gen)'
#  'AMD Ryzen 9 Octa Core Processor (5th Gen)'
#  'Intel Core i9 Processor (10th Gen)' 'Intel Celeron Quad Core Processor'
#  'AMD Ryzen 5 Dual Core Processor (5th Gen)'
#  'Intel Core i9 Processor (11th Gen)' 'AMD Ryzen 7 Quad Core Processor'
#  'Intel Core i5 Processor (7th Gen)' 'Intel Core i5 Processor (9th Gen)'
#  'AMD Ryzen 7 Hexa Core Processor' 'Intel Core i5 Processor (8th Gen)'
#  'Intel Core i7 Processor (8th Gen)' 'Intel Core i7 Processor (7th Gen)'
#  'AMD Ryzen 9 Octa Core Processor (10th Gen)'
#  'Intel Core i3 Processor (7th Gen)' 'Intel Core i9 Processor (8th Gen)'
#  'AMD APU Dual Core A6 Processor'
#  'Intel Celeron Dual Core Processor (4th Gen)'
#  'Intel Core i5 Processor (5th Gen)' 'Intel Core i5 Processor (4th Gen)'
#  'Intel Core i7 Processor (9th Gen)'
#  'MediaTek MediaTek Kompanio 500 Processor']

# %%
# Ottieni i nomi delle colonne
columns_to_check = df.columns[4:5]

# Crea un dizionario per memorizzare le istanze univoche per ogni colonna
unique_instances = {}

# Itera attraverso le colonne e ottieni le istanze univoche
for col in columns_to_check:
    unique_instances[col] = df[col].unique()

# Stampa le istanze univoche per ogni colonna
for col, unique_vals in unique_instances.items():
    print(f"Colonna: {col}")
    print(unique_vals)
    print()
# Out:
# Colonna: ram
# ['16 GB DDR4 RAM' '8 GB DDR4 RAM' '4 GB DDR4 RAM' '16 GB LPDDR5 RAM'
#  '16 GB DDR5 RAM' '4 GB LPDDR4X RAM' '8 GB LPDDR4X RAM' '32 GB LPDDR5 RAM'
#  '4 GB LPDDR4 RAM' '16 GB LPDDR4X RAM' '8 GB DDR5 RAM'
#  '8 GB Unified Memory RAM' '32 GB Unified Memory RAM'
#  '16 GB Unified Memory RAM' '32 GB DDR5 RAM' '32 GB DDR4 RAM'
#  '8 GB DDR3 RAM' '8 GB LPDDR3 RAM' '16 GB LPDDR3 RAM' '16 GB DDR3 RAM']

# %%
# Ottieni i nomi delle colonne
columns_to_check = df.columns[5:6]

# Crea un dizionario per memorizzare le istanze univoche per ogni colonna
unique_instances = {}

# Itera attraverso le colonne e ottieni le istanze univoche
for col in columns_to_check:
    unique_instances[col] = df[col].unique()

# Stampa le istanze univoche per ogni colonna
for col, unique_vals in unique_instances.items():
    print(f"Colonna: {col}")
    print(unique_vals)
    print()
# Out:
# Colonna: os
# ['Windows 11 Operating System' '64 bit Windows 11 Operating System'
#  'DOS Operating System' 'Mac OS Operating System'
#  '64 bit Windows 10 Operating System' '32 bit Windows 11 Operating System'
#  'Chrome Operating System' '64 bit Chrome Operating System'
#  'Windows 10 Operating System' '64 bit DOS Operating System'
#  '64 bit Windows 8 Operating System']

# %%
# Ottieni i nomi delle colonne
columns_to_check = df.columns[6:7]

# Crea un dizionario per memorizzare le istanze univoche per ogni colonna
unique_instances = {}

# Itera attraverso le colonne e ottieni le istanze univoche
for col in columns_to_check:
    unique_instances[col] = df[col].unique()

# Stampa le istanze univoche per ogni colonna
for col, unique_vals in unique_instances.items():
    print(f"Colonna: {col}")
    print(unique_vals)
    print()
# Out:
# Colonna: storage
# ['512 GB SSD' '1 TB HDD|256 GB SSD' '256 GB SSD' '1 TB SSD' '2 TB SSD'
#  '1 TB HDD|512 GB SSD' '1 TB HDD' '128 GB SSD' '256 GB HDD|256 GB SSD'
#  '1 TB HDD|128 GB SSD'
#  'PCI-e SSD (NVMe) ready,Silver-Lining Print Keyboard,Matrix Display (Extend),Cooler Boost 5,Hi-Res Audio,Nahimic 3,144Hz Panel,Thin Bezel,RGB Gaming Keyboard,Speaker Tuning Engine,MSI Center'
#  'PCI-e Gen4 SSD?SHIFT?Matrix Display (Extend)?Cooler Boost 3?Thunderbolt 4?Finger Print Security?True Color 2.0?Hi-Res Audio?Nahimic 3? 4-Sided Thin bezel?MSI Center?Silky Smooth Touchpad?Military-Grade Durability'
#  '2 TB HDD' '512 GB HDD|512 GB SSD' '256 GB HDD']

# %%
# Ottieni i nomi delle colonne
columns_to_check = df.columns[7:8]

# Crea un dizionario per memorizzare le istanze univoche per ogni colonna
unique_instances = {}

# Itera attraverso le colonne e ottieni le istanze univoche
for col in columns_to_check:
    unique_instances[col] = df[col].unique()

# Stampa le istanze univoche per ogni colonna
for col, unique_vals in unique_instances.items():
    print(f"Colonna: {col}")
    print(unique_vals)
    print()
# Out:
# Colonna: display(in inch)
# [15.6  14.   13.3  17.3  11.6  16.   16.1  13.6  13.4  16.2  14.2  14.1
#  14.96 35.   16.6  15.  ]

# %%
# Ottieni i nomi delle colonne
columns_to_check = df.columns[8:9]

# Crea un dizionario per memorizzare le istanze univoche per ogni colonna
unique_instances = {}

# Itera attraverso le colonne e ottieni le istanze univoche
for col in columns_to_check:
    unique_instances[col] = df[col].unique()

# Stampa le istanze univoche per ogni colonna
for col, unique_vals in unique_instances.items():
    print(f"Colonna: {col}")
    print(unique_vals)
    print()
# Out:
# Colonna: rating
# [4.5 4.4 4.3 3.8 4.7 4.1 4.  4.2 5.  3.7 3.6 4.9 4.8 4.6 3.1 3.9 3.  3.5
#  3.3 1.6]

# %%
# Ottieni i nomi delle colonne
columns_to_check = df.columns[9:10]

# Crea un dizionario per memorizzare le istanze univoche per ogni colonna
unique_instances = {}

# Itera attraverso le colonne e ottieni le istanze univoche
for col in columns_to_check:
    unique_instances[col] = df[col].unique()

# Stampa le istanze univoche per ogni colonna
for col, unique_vals in unique_instances.items():
    print(f"Colonna: {col}")
    print(unique_vals)
    print()
# Out:
# Colonna
#  5.700e+01 1.940e+02 5.000e+01 3.070e+02 1.590e+02 5.180e+02 2.320e+02
#  5.800e+01 3.640e+02 4.300e+02 1.640e+02 1.420e+02 2.270e+02 6.870e+02]

# %%
# Ottieni i nomi delle colonne
columns_to_check = df.columns[11:12]

# Crea un dizionario per memorizzare le istanze univoche per ogni colonna
unique_instances = {}

# Itera attraverso le colonne e ottieni le istanze univoche
for col in columns_to_check:
    unique_instances[col] = df[col].unique()

# Stampa le istanze univoche per ogni colonna
for col, unique_vals in unique_instances.items():
    print(f"Colonna: {col}")
    print(unique_vals)
    print()
# Out:
# Colonna: price(in EUR)
# [ 692.89   412.5    549.89   373.89   208.89   956.89   263.89   373.989
#   428.89   296.89   736.89   417.89   626.89   439.89   516.89   540.353
#   527.89   951.5    494.89   582.89   372.79   423.5    504.999  450.45
#  1099.89   659.89   638.198  425.689  362.89   593.89   714.89  1209.89
#   749.254  616.539  285.89   517.429  747.89   450.89  1759.89   824.89
#   681.89   637.89   571.89   197.89   175.89   472.89   604.89   340.89
#   560.89   879.89   251.9    371.261  505.89   687.489  846.989  973.489
#   725.89   945.89  1539.89  1248.39   989.89   461.89   703.89   978.89
#   846.89  1154.89   868.89   758.89  1055.89   675.4    467.39   487.19
#  1319.89  1429.89  1781.89   813.89  3387.89   307.89   682.55   453.09
#   615.89   352.     977.9    802.89   381.59  2352.834  395.89   860.09
#   478.39   406.89  1341.89   967.89   471.9    973.39  1550.89   384.89
#   418.319  351.89   548.79   663.19   857.89  1039.5   1704.89  1264.89
#   890.89   434.39  3101.89   347.171  538.89   951.39  1616.89   346.39
#   676.5   2518.208 3799.29   835.89  1429.879  687.39   670.89  1210.
#   566.852 1585.1    230.89   725.989  219.89   710.49  1268.3    291.39
#   506.44   274.989  752.4    577.39   779.9    392.689  934.89   478.5
#  1539.989 1721.39   181.39  2750.    1600.489  646.8   1116.39   769.89
#   800.69   661.43  1737.89   961.29  2199.89   469.59  2452.89  1716.99
#   768.79  1198.89   643.5    365.2    460.79   791.89  1165.89   647.9
#  2320.89  1655.39  1803.89   461.989  977.79   267.19   416.79  1429.989
#  2043.69   797.39   681.989 1032.9    643.489  560.813  517.99   442.2
#   570.79   390.5    313.39  1611.39   693.99  1088.89   449.79   447.59
#   486.09   252.89  1180.641 1660.89   869.     448.668  467.5    428.989
#  1495.89   972.29  1244.144  493.9    665.39   841.39   471.79  1220.89
#   318.89  2306.59   897.6   1352.89   337.15   578.325  438.79   269.39
#   696.19   604.56  1044.89   461.56   762.861  704.    2969.89   556.6
#  1191.19   395.56   880.     755.59  1990.89   442.75   680.79  1072.5
#   819.39  1649.89   940.489 1673.364 2271.39   496.386 1594.89   731.39
#   473.99   368.39   439.989 1098.9   1164.79   598.95   713.031  691.79
#   272.8    886.49   436.59   717.2    436.073  402.6    445.489  871.838
#  1397.     627.99   901.978 2067.89   735.79   186.89   808.39   249.37 ]
