# %% [markdown]
# %% [markdown]<br>
# ## Classificazione e Clustering Pokemon<br>
# ### Classificazione<br>
# #### Cella 1: Importazioni e Preprocessing

# %% [markdown]
# %%

# %%
import pandas as pd
import numpy as np
import ast
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MultiLabelBinarizer, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense # type: ignore
from tensorflow.keras.models import Model, Sequential # type: ignore
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import os
os.environ["LOKY_MAX_CPU_COUNT"] = "4" # in order to avoid memory error

# %% [markdown]
# %%<br>
# Carica il dataset

# %%
df = pd.read_csv("pokemon.csv")

# %% [markdown]
# %%<br>
# Elimina le colonne duplicate

# %%
df.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# %%<br>
# Seleziona le colonne numeriche

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns

# %% [markdown]
# Sostituisci i valori mancanti con la mediana di ciascuna colonna numerica

# %%
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %% [markdown]
# %%<br>
# Seleziona le colonne di tipo object (categoriche)

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

# %% [markdown]
# Sostituisci i valori mancanti con "Unknown" (o con il mode della colonna)

# %%
df[categorical_cols] = df[categorical_cols].fillna("Unknown")

# %% [markdown]
# %%<br>
# Converti le colonne stringa in liste Python

# %%
df['type'] = df['type'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])
df['charged_moves'] = df['charged_moves'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])
df['fast_moves'] = df['fast_moves'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])

# %% [markdown]
# %%<br>
# Combina le mosse in un'unica lista

# %%
df['all_moves'] = df['charged_moves'] + df['fast_moves']

# %% [markdown]
# %%<br>
# Seleziona le feature numeriche

# %%
numeric_features = ['base_attack', 'base_defense', 'base_stamina', 'max_cp',
                    'attack_probability', 'dodge_probability',
                    'max_pokemon_action_frequency', 'min_pokemon_action_frequency']
X_numeric = df[numeric_features].values

# %% [markdown]
# %%<br>
# Normalizza le feature numeriche

# %%
scaler = StandardScaler()
X_numeric_scaled = scaler.fit_transform(X_numeric)

# %% [markdown]
# %%<br>
# Codifica la colonna "type" usando MultiLabelBinarizer

# %%
mlb_type = MultiLabelBinarizer()
X_type = mlb_type.fit_transform(df['type'])

# %% [markdown]
# %%<br>
# Codifica le mosse

# %%
mlb_moves = MultiLabelBinarizer()
X_moves = mlb_moves.fit_transform(df['all_moves'])

# %% [markdown]
# %%<br>
# Combina tutte le feature in un unico vettore

# %%
X_combined = np.concatenate([X_numeric_scaled, X_type, X_moves], axis=1)
print("Dimensione input combinato:", X_combined.shape)
# Out:
# Dimensione input combinato: (1007, 263)

# %% [markdown]
# %% [markdown]<br>
# #### Cella 2: Costruzione e Addestramento dell'Autoencoder

# %% [markdown]
# %%<br>
# Definizione dei parametri

# %%
input_dim = X_combined.shape[1]
encoding_dim = 16  # Dimensione dello spazio latente

# %% [markdown]
# %%<br>
# Definizione dell'architettura dell'autoencoder

# %%
input_layer = Input(shape=(input_dim,))
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(64, activation='relu')(encoded)
latent = Dense(encoding_dim, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(latent)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(input_dim, activation='linear')(decoded)

# %% [markdown]
# %%<br>
# Costruzione del modello

# %%
autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# %% [markdown]
# %%<br>
# Addestramento dell'autoencoder

# %%
autoencoder.fit(X_combined, X_combined, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0550 - val_loss: 0.0456
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0466 - val_loss: 0.0364
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0432 - val_loss: 0.0328
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0421 - val_loss: 0.0304
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0353 - val_loss: 0.0292
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0355 - val_loss: 0.0280
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0366 - val_loss: 0.0267
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0308 - val_loss: 0.0260
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0296 - val_loss: 0.0254
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0277 - val_loss: 0.0250
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0258 - val_loss: 0.0247
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0265 - val_loss: 0.0244
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0274 - val_loss: 0.0241
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242 - val_loss: 0.0240
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0239 - val_loss: 0.0238
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0239 - val_loss: 0.0237
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0228 - val_loss: 0.0235
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0229 - val_loss: 0.0234
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0222 - val_loss: 0.0234
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0224 - val_loss: 0.0232
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0221 - val_loss: 0.0228
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0229 - val_loss: 0.0228
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0235 - val_loss: 0.0229
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0216 - val_loss: 0.0245
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0311 - val_loss: 0.0278
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0293 - val_loss: 0.0241
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0255 - val_loss: 0.0231
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0246 - val_loss: 0.0227
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0224 - val_loss: 0.0225
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - val_loss: 0.0222
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206 - val_loss: 0.0221
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0207 - val_loss: 0.0220
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - val_loss: 0.0220
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0200 - val_loss: 0.0219
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - val_loss: 0.0218
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0198 - val_loss: 0.0217
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - val_loss: 0.0217
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - val_loss: 0.0216
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - val_loss: 0.0216
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194 - val_loss: 0.0215
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - val_loss: 0.0215
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0192 - val_loss: 0.0214
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191 - val_loss: 0.0213
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0213
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - val_loss: 0.0215
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0212
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - val_loss: 0.0215
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193 - val_loss: 0.0212
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186 - val_loss: 0.0211
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0211

# %% [markdown]
# %%<br>
# Estrazione del modello encoder per ottenere la rappresentazione latente

# %%
encoder = Model(inputs=input_layer, outputs=latent)
X_latent = encoder.predict(X_combined)
print("Dimensione rappresentazione latente:", X_latent.shape)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Dimensione rappresentazione latente: (1007, 16)

# %% [markdown]
# %% [markdown]<br>
# #### Cella 3: Analisi della Rappresentazione Latente

# %% [markdown]
# %%<br>
# Distribuzione delle prime due componenti della rappresentazione latente

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_latent[:, 0], y=X_latent[:, 1], alpha=0.5)
plt.xlabel("Latent Dim 1")
plt.ylabel("Latent Dim 2")
plt.title("Distribuzione della Rappresentazione Latente")
plt.show()

# %% [markdown]
# %% [markdown]<br>
# #### Cella 4: Clustering con K-Means e Silhouette Score

# %% [markdown]
# %%<br>
# Testiamo diversi valori di K

# %%
wcss = []  # Within-Cluster Sum of Squares
silhouette_scores = []

# %%
for k in range(2, 11):  # Da 2 a 10 cluster
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X_latent)
    wcss.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(X_latent, labels))

# %% [markdown]
# %%<br>
# Grafico del metodo del gomito

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(2, 11), wcss, marker='o', linestyle='--')
plt.xlabel("Numero di cluster (K)")
plt.ylabel("WCSS")
plt.title("Metodo del Gomito")
# Out:
# Text(0.5, 1.0, 'Metodo del Gomito')

# %% [markdown]
# %%<br>
# Grafico del silhouette score

# %%
plt.subplot(1, 2, 2)
plt.plot(range(2, 11), silhouette_scores, marker='s', linestyle='-')
plt.xlabel("Numero di cluster (K)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score per diversi K")
plt.show()

# %% [markdown]
# %%<br>
# Addestriamo K-Means con il numero ottimale di cluster (es. K=3)

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_latent)

# %% [markdown]
# %%<br>
# Aggiungiamo le etichette dei cluster al dataset

# %%
df["cluster"] = clusters

# %% [markdown]
# %%<br>
# Grafico della distribuzione dei cluster

# %%
sns.countplot(x=df["cluster"], hue=df["cluster"], palette="viridis", legend=False)
plt.title("Distribuzione dei Cluster")
plt.xlabel("Cluster")
plt.ylabel("Conteggio")
plt.show()

# %% [markdown]
# %% [markdown]<br>
# #### Cella 5: Random Forest Classifier

# %% [markdown]
# %%<br>
# Classificazione con Random Forest

# %%
features = numeric_features
target = "rarity"

# %% [markdown]
# %%<br>
# Questo trasforma le etichette categoriali in numeri interi

# %%
label_encoder = LabelEncoder()
df[target] = label_encoder.fit_transform(df[target])

# %% [markdown]
# %%<br>
# Divide il dataset in set di addestramento e di test<br>
# X_train e X_test contengono le caratteristiche (features)<br>
# y_train e y_test contengono le etichette (target)

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# %%<br>
# Prevede le etichette per il set di test

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# %%<br>
# Matrice di confusione

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", xticklabels=label_encoder.classes_,yticklabels=label_encoder.classes_)
plt.xlabel("Predetto")
plt.ylabel("Reale")
plt.title("Matrice di Confusione")
plt.show()

# %% [markdown]
# %%<br>
# Report di classificazione

# %%
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#    Legendary       0.67      0.62      0.64        13
#       Mythic       1.00      0.25      0.40         4
#     Standard       0.96      0.98      0.97       184
#  Ultra beast       1.00      0.00      0.00         1
#
#     accuracy                           0.94       202
#    macro avg       0.91      0.46      0.50       202
# weighted avg       0.94      0.94      0.93       202

# %% [markdown]
# %%<br>
# Importanza delle feature

# %%
feature_importances = pd.Series(clf.feature_importances_, index=features).sort_values(ascending=False)
plt.figure(figsize=(10, 6))
feature_importances.plot(kind='bar', color='skyblue')
plt.title("Importanza delle Feature")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# %%<br>
# Heatmap della correlazione

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df[features + [target]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap della Correlazione")
plt.show()

# %% [markdown]
# %%<br>
# Distribuzione della raritÃ

# %%
sns.countplot(x=df[target], hue=df[target], palette="viridis", legend=False)
plt.title("Distribuzione della RaritÃ ")
plt.xlabel("RaritÃ ")
plt.ylabel("Conteggio")
plt.show()

# %% [markdown]
# %% [markdown]<br>
# #### Cella 6: Definizione del Target PvP vs. PvE

# %% [markdown]
# %%<br>
# Definiamo insiemi euristici per le mosse

# %%
pvp_moves = {'Counter', 'Quick Attack', 'Vine Whip', 'Tackle', 'Bug Bite', 'Ember', 
            'Scratch', 'Water Gun', 'Bubble', 'Wing Attack', 'Peck'}
pve_moves = {'Hydro Cannon', 'Blast Burn', 'Solar Beam', 'Flamethrower', 'Dragon Claw', 
            'Skull Bash', 'Ice Beam', 'Hydro Pump'}

# %% [markdown]
# %%<br>
# Funzione per assegnare lo stile PvP (0) o PvE (1)

# %%
def assign_style(row):
    moves = set(row['all_moves'])
    if moves.intersection(pvp_moves) and not moves.intersection(pve_moves):
        return 0  # PvP
    else:
        return 1  # PvE

# %% [markdown]
# %%

# %%
df['style'] = df.apply(assign_style, axis=1)
y = df['style'].values
print("Distribuzione stili:\n", pd.Series(y).value_counts())
# Out:
# Distribuzione stili:
#  1    642
# 0    365
# Name: count, dtype: int64

# %% [markdown]
# %% [markdown]<br>
# #### Cella 7: Classificazione Supervisionata sui Dati Latenti

# %% [markdown]
# %%<br>
# Suddividi i dati in training e test

# %%
X_train, X_test, y_train, y_test = train_test_split(X_latent, y, test_size=0.2, random_state=42)

# %% [markdown]
# %%<br>
# Costruzione del classificatore (rete neurale)

# %%
classifier = Sequential()
classifier.add(Dense(32, activation='relu', input_dim=encoding_dim))
classifier.add(Dense(16, activation='relu'))
classifier.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\gabri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
classifier.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6494 - loss: 0.6521 - val_accuracy: 0.6832 - val_loss: 0.6106
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6603 - loss: 0.6189 - val_accuracy: 0.6894 - val_loss: 0.5929
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6904 - loss: 0.6036 - val_accuracy: 0.7205 - val_loss: 0.5739
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7054 - loss: 0.6020 - val_accuracy: 0.7081 - val_loss: 0.5673
# Epoch 5/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7281 - loss: 0.5695 - val_accuracy: 0.7391 - val_loss: 0.5512
# Epoch 6/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6900 - loss: 0.5888 - val_accuracy: 0.7391 - val_loss: 0.5465
# Epoch 7/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6897 - loss: 0.5843 - val_accuracy: 0.7205 - val_loss: 0.5420
# Epoch 8/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7248 - loss: 0.5555 - val_accuracy: 0.7205 - val_loss: 0.5352
# Epoch 9/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7190 - loss: 0.5512 - val_accuracy: 0.7205 - val_loss: 0.5346
# Epoch 10/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7284 - loss: 0.5461 - val_accuracy: 0.7143 - val_loss: 0.5323
# Epoch 11/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7119 - loss: 0.5429 - val_accuracy: 0.7205 - val_loss: 0.5291
# Epoch 12/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7237 - loss: 0.5506 - val_accuracy: 0.7391 - val_loss: 0.5270
# Epoch 13/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7309 - loss: 0.5548 - val_accuracy: 0.7267 - val_loss: 0.5247
# Epoch 14/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7366 - loss: 0.5380 - val_accuracy: 0.7205 - val_loss: 0.5228
# Epoch 15/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7445 - loss: 0.5323 - val_accuracy: 0.7329 - val_loss: 0.5246
# Epoch 16/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7591 - loss: 0.5170 - val_accuracy: 0.7329 - val_loss: 0.5204
# Epoch 17/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7328 - loss: 0.5101 - val_accuracy: 0.7516 - val_loss: 0.5260
# Epoch 18/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7551 - loss: 0.5042 - val_accuracy: 0.7205 - val_loss: 0.5202
# Epoch 19/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7643 - loss: 0.4982 - val_accuracy: 0.7391 - val_loss: 0.5204
# Epoch 20/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8040 - loss: 0.4689 - val_accuracy: 0.7453 - val_loss: 0.5211
# Epoch 21/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7711 - loss: 0.4804 - val_accuracy: 0.7516 - val_loss: 0.5352
# Epoch 22/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7681 - loss: 0.5139 - val_accuracy: 0.7329 - val_loss: 0.5169
# Epoch 23/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7719 - loss: 0.4864 - val_accuracy: 0.7143 - val_loss: 0.5152
# Epoch 24/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7844 - loss: 0.4872 - val_accuracy: 0.7143 - val_loss: 0.5158
# Epoch 25/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7657 - loss: 0.5043 - val_accuracy: 0.7453 - val_loss: 0.5155
# Epoch 26/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7905 - loss: 0.4688 - val_accuracy: 0.7640 - val_loss: 0.5273
# Epoch 27/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7664 - loss: 0.4903 - val_accuracy: 0.7453 - val_loss: 0.5143
# Epoch 28/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7852 - loss: 0.4856 - val_accuracy: 0.7391 - val_loss: 0.5133
# Epoch 29/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7765 - loss: 0.4770 - val_accuracy: 0.7453 - val_loss: 0.5166
# Epoch 30/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7744 - loss: 0.4672 - val_accuracy: 0.7329 - val_loss: 0.5181
# Epoch 31/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8015 - loss: 0.4627 - val_accuracy: 0.7329 - val_loss: 0.5282
# Epoch 32/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7574 - loss: 0.5121 - val_accuracy: 0.7329 - val_loss: 0.5130
# Epoch 33/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7504 - loss: 0.4780 - val_accuracy: 0.7329 - val_loss: 0.5410
# Epoch 34/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7782 - loss: 0.4924 - val_accuracy: 0.7329 - val_loss: 0.5225
# Epoch 35/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7795 - loss: 0.4783 - val_accuracy: 0.7391 - val_loss: 0.5184
# Epoch 36/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7962 - loss: 0.4534 - val_accuracy: 0.7267 - val_loss: 0.5194
# Epoch 37/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8070 - loss: 0.4387 - val_accuracy: 0.7391 - val_loss: 0.5295
# Epoch 38/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7822 - loss: 0.4721 - val_accuracy: 0.7391 - val_loss: 0.5188
# Epoch 39/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7810 - loss: 0.4802 - val_accuracy: 0.7329 - val_loss: 0.5173
# Epoch 40/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8058 - loss: 0.4345 - val_accuracy: 0.7329 - val_loss: 0.5265
# Epoch 41/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8311 - loss: 0.4113 - val_accuracy: 0.7143 - val_loss: 0.5319
# Epoch 42/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8128 - loss: 0.4187 - val_accuracy: 0.7329 - val_loss: 0.5250
# Epoch 43/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7786 - loss: 0.4603 - val_accuracy: 0.7391 - val_loss: 0.5195
# Epoch 44/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8115 - loss: 0.4166 - val_accuracy: 0.7205 - val_loss: 0.5290
# Epoch 45/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8047 - loss: 0.4193 - val_accuracy: 0.7329 - val_loss: 0.5310
# Epoch 46/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8243 - loss: 0.4319 - val_accuracy: 0.7391 - val_loss: 0.5208
# Epoch 47/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8025 - loss: 0.4284 - val_accuracy: 0.7329 - val_loss: 0.5221
# Epoch 48/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8427 - loss: 0.3893 - val_accuracy: 0.7329 - val_loss: 0.5368
# Epoch 49/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7999 - loss: 0.4378 - val_accuracy: 0.7329 - val_loss: 0.5231
# Epoch 50/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8192 - loss: 0.4168 - val_accuracy: 0.7329 - val_loss: 0.5501

# %% [markdown]
# %%<br>
# Valutazione del modello

# %%
loss, accuracy = classifier.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7565 - loss: 0.5732
# Test Accuracy: 0.7524752616882324

# %% [markdown]
# %% [markdown]<br>
# ### Clustering<br>
# #### Cella 1: Trovare il numero ottimale di cluster (Metodo del Gomito)

# %% [markdown]
# %%

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import os
os.environ["LOKY_MAX_CPU_COUNT"] = "4"  # Cambia il numero in base ai core del tuo PC

# %% [markdown]
# %%<br>
# Testiamo diversi valori di K

# %%
wcss = []  # Within-Cluster Sum of Squares

# %%
for k in range(1, 11):  # Da 1 a 10 cluster
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_latent)
    wcss.append(kmeans.inertia_)  # Inertia = somma delle distanze dei punti dal centroide

# %% [markdown]
# %%<br>
# Grafico del metodo del gomito

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.xlabel("Numero di cluster (K)")
plt.ylabel("WCSS (Within-Cluster Sum of Squares)")
plt.title("Metodo del Gomito per trovare il numero ottimale di cluster")
plt.show()

# %% [markdown]
# %% [markdown]<br>
# #### Cella 2: Applicare K-Means con il numero ottimale di cluster

# %% [markdown]
# %%<br>
# Addestriamo K-Means con il numero ottimale di cluster (es. K=3)

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_latent)

# %% [markdown]
# %%<br>
# Aggiungiamo le etichette dei cluster al dataset

# %%
df["cluster"] = clusters

# %% [markdown]
# %%<br>
# Visualizziamo la distribuzione dei cluster

# %%
print(df["cluster"].value_counts())
# Out:
# cluster
# 1    768
# 0    237
# 2      2
# Name: count, dtype: int64

# %% [markdown]
# %% [markdown]<br>
# #### Cella 3: Visualizzare i cluster con PCA (2D)

# %% [markdown]
# %%<br>
# Riduzione a 2 componenti principali

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_latent)

# %% [markdown]
# %%

# %% [markdown]
# Creiamo un DataFrame con i dati ridotti e le etichette dei cluster

# %%
df_pca = pd.DataFrame(X_pca, columns=["PC1", "PC2"])
df_pca["cluster"] = clusters

# %% [markdown]
# %%<br>
# Grafico dei cluster

# %%
plt.figure(figsize=(8, 6))
for cluster in range(kmeans.n_clusters):
    subset = df_pca[df_pca["cluster"] == cluster]
    plt.scatter(subset["PC1"], subset["PC2"], label=f"Cluster {cluster}")

# %% [markdown]
# %%

# %% [markdown]
# %%

# %% [markdown]
# %%

# %% [markdown]
# %%

# %% [markdown]
# %%

# %% [markdown]
# %%

# %% [markdown]
# %%

# %% [markdown]
# %%

# %% [markdown]
# %%

# %% [markdown]
# %%
